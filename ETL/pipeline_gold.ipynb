# %% [markdown]
# <a href="https://colab.research.google.com/github/datajoedata/e-Commerce-Sales-Analysis-Target-Brazil/blob/main/ETL/pipeline_gold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I - Imports e loads

# %% [markdown]
# ### 1.1 - Imports

# %%
from google.colab import drive
import pandas as pd
import os
from IPython.display import display

# %% [markdown]
# ### 1.2 - Montagem drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Caminho para pastas

caminho_silver = '/content/drive/MyDrive/Analise_de_Vendas_E-commerce/silver'
caminho_gold = '/content/drive/MyDrive/Analise_de_Vendas_E-commerce/gold'

os.makedirs(caminho_gold, exist_ok=True)

# %%
# Carregar arquivos
clientes_df = pd.read_parquet(f'{caminho_silver}/clientes.parquet')
vendedores_df = pd.read_parquet(f'{caminho_silver}/vendedores.parquet')
itens_pedidos_df = pd.read_parquet(f'{caminho_silver}/itens_pedidos.parquet')
geolocalizacao_df = pd.read_parquet(f'{caminho_silver}/geolocalizacao.parquet')
pagamentos_df = pd.read_parquet(f'{caminho_silver}/pagamentos.parquet')
pedidos_df = pd.read_parquet(f'{caminho_silver}/pedidos.parquet')
produtos_df = pd.read_parquet(f'{caminho_silver}/produtos.parquet')

# %% [markdown]
# ### 1.3 - Verificação carregamento

# %%
# Exibindo as primeiras linhas de cada DataFrame para verificação
display(clientes_df.head(3), vendedores_df.head(3), itens_pedidos_df.head(3),
        geolocalizacao_df.head(3), pagamentos_df.head(3), pedidos_df.head(3), produtos_df.head(3))
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
#
#   customer_zip_code_prefix          customer_city customer_state
# 0                    14409                 franca             SP
# 1                     9790  sao bernardo do campo             SP
# 2                     1151              sao paulo             SP
#                           seller_id seller_zip_code_prefix     seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                  13023        campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                  13844      mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                  20031  rio de janeiro
#
#   seller_state
# 0           SP
# 1           SP
# 2           RJ
#                            order_id order_item_id  \
# ...

# %% [markdown]
# # II - Preparação e Enriquecimento dos Dados

# %% [markdown]
# #### 2.1 - Cálculo do Volume e Densidade dos Produtos

# %%
# Calcular o volume dos produtos em cm³
produtos_df['product_volume_cm3'] = (
    produtos_df['product_length_cm'] *
    produtos_df['product_height_cm'] *
    produtos_df['product_width_cm']
)

# Calcular a densidade dos produtos em g/cm³
produtos_df['product_density_g_per_cm3'] = (
    produtos_df['product_weight_g'] / produtos_df['product_volume_cm3']
)

# %% [markdown]
# ### 2.2 - Mesclando Características dos Produtos nos Itens de Pedido

# %%
# Adicionar informações de produto aos itens pedidos
itens_pedidos_df = itens_pedidos_df.merge(
    produtos_df[['product_id', 'product_category', 'product_volume_cm3', 'product_density_g_per_cm3']],
    on='product_id',
    how='left'
)

# %% [markdown]
# ### 2.3 - Adicionando Informações de Clientes aos Pedidos

# %%
# Adicionar informações de cliente aos pedidos
pedidos_df = pedidos_df.merge(
    clientes_df[['customer_id', 'customer_unique_id']],
    on='customer_id',
    how='left'
)

# %% [markdown]
# ### 2.4 - Adicionando 'customer_unique_id' aos Itens de Pedido

# %%
# Adiciona 'customer_unique_id' ao 'itens_pedidos_df' mesclando com 'pedidos_df'
itens_pedidos_df = itens_pedidos_df.merge(
    pedidos_df[['order_id', 'customer_id', 'customer_unique_id']],
    on='order_id',
    how='left'
)

# %% [markdown]
# ### 2.5 - Calculando a Margem Bruta

# %%
# Calcular a margem bruta de cada item pedido
itens_pedidos_df['margem_bruta'] = itens_pedidos_df['price'] - itens_pedidos_df['freight_value']

# %% [markdown]
# ### 2.6 - Criando a Tabela de Vendas

# %%
# Criar a tabela de vendas (tabela fato)
vendas_df = itens_pedidos_df[[
    'order_id',
    'order_item_id',
    'product_id',
    'seller_id',
    'customer_id',
    'customer_unique_id',
    'price',
    'freight_value',
    'margem_bruta',
    'shipping_limit_date'
]]

# %% [markdown]
# ### 2.7 - Agrupando prefixos dos CEP's

# %%
# Agregar a tabela de geolocalização por prefixo de CEP
geolocalizacao_agg = geolocalizacao_df.groupby('geolocation_zip_code_prefix').agg({
    'geolocation_lat': 'mean',
    'geolocation_lng': 'mean'
}).reset_index()

# %% [markdown]
# # III - Criação das Tabelas de Dimensões

# %% [markdown]
# ### 3.1 - Dimensão Produto

# %%
# Criar a tabela de dimensão produto
dim_produto_df = produtos_df[[
    'product_id',
    'product_category',
    'product_name_length',
    'product_description_length',
    'product_photos_qty',
    'product_weight_g',
    'product_length_cm',
    'product_height_cm',
    'product_width_cm',
    'product_volume_cm3',
    'product_density_g_per_cm3'
]].drop_duplicates()

# Renomear colunas para padronização
dim_produto_df.rename(columns={'product_id': 'id_produto'}, inplace=True)

# %% [markdown]
# ### 3.2 - Resumo e agrupamento de categoria em produtos

# %%
# Mapeamento de categorias para grupos principais

categoria_grupos = {
    # Moda e Acessórios
    'fashion calcados': 'Moda e Acessórios',
    'fashion bags and accessories': 'Moda e Acessórios',
    'fashion underwear and beach fashion': 'Moda e Acessórios',
    "fashion men's clothing": 'Moda e Acessórios',
    "fashion women's clothing": 'Moda e Acessórios',
    "fashion children's clothing": 'Moda e Acessórios',
    'fashion sport': 'Moda e Acessórios',

    # Casa e Decoração
    'housewares': 'Casa e Decoração',
    'furniture decoration': 'Casa e Decoração',
    'bed table bath': 'Casa e Decoração',
    'furniture office': 'Casa e Decoração',
    'room furniture': 'Casa e Decoração',
    'house comfort': 'Casa e Decoração',
    'house comfort 2': 'Casa e Decoração',
    'furniture': 'Casa e Decoração',
    'furniture kitchen service area dinner and garden': 'Casa e Decoração',
    'casa construcao': 'Casa e Decoração',

    # Ferramentas e Construção
    'construction security tools': 'Ferramentas e Construção',
    'construction tools construction': 'Ferramentas e Construção',
    'construction tools tools': 'Ferramentas e Construção',
    'construction tools illumination': 'Ferramentas e Construção',
    'construction tools garden': 'Ferramentas e Construção',
    'garden tools': 'Ferramentas e Construção',
    'signalization and safety': 'Ferramentas e Construção',

    # Eletrônicos e Tecnologia
    'electronics': 'Eletrônicos e Tecnologia',
    'telephony': 'Eletrônicos e Tecnologia',
    'fixed telephony': 'Eletrônicos e Tecnologia',
    'computer accessories': 'Eletrônicos e Tecnologia',
    'pcs': 'Eletrônicos e Tecnologia',
    'pc gamer': 'Eletrônicos e Tecnologia',
    'image import tablets': 'Eletrônicos e Tecnologia',
    'cine photo': 'Eletrônicos e Tecnologia',
    'games consoles': 'Eletrônicos e Tecnologia',
    'audio': 'Eletrônicos e Tecnologia',
    'blu ray dvds': 'Eletrônicos e Tecnologia',

    # Livros, Música e Filmes
    'general interest books': 'Livros, Música e Filmes',
    'technical books': 'Livros, Música e Filmes',
    'imported books': 'Livros, Música e Filmes',
    'cds music dvds': 'Livros, Música e Filmes',
    'song': 'Livros, Música e Filmes',
    'arts and crafts': 'Livros, Música e Filmes',

    # Saúde e Beleza
    'perfumery': 'Saúde e Beleza',
    'health beauty': 'Saúde e Beleza',
    'hygiene diapers': 'Saúde e Beleza',

    # Bebês e Crianças
    'babies': 'Bebês e Crianças',
    'toys': 'Bebês e Crianças',
    "fashion children's clothing": 'Bebês e Crianças',

    # Comida e Bebidas
    'drinks': 'Comida e Bebidas',
    'drink foods': 'Comida e Bebidas',
    'foods': 'Comida e Bebidas',
    'la cuisine': 'Comida e Bebidas',
    'house pastals oven and cafe': 'Comida e Bebidas',

    # Esportes e Lazer
    'sport leisure': 'Esportes e Lazer',
    'cool stuff': 'Esportes e Lazer',
    'christmas articles': 'Esportes e Lazer',
    'party articles': 'Esportes e Lazer',

    # Outros
    'art': 'Outros',
    'pet shop': 'Outros',
    'insurance and services': 'Outros',
    'market place': 'Outros',
    'industry commerce and business': 'Outros',
    'agro industria e comercio': 'Outros',
    None: 'Outros'
}


# Traduzir a categoria dos produtos na tabela produtos
dim_produto_df['categoria_produtos'] = dim_produto_df['product_category'].map(categoria_grupos)

# Substituir valores Null (NaN) por 'Outros'
dim_produto_df['categoria_produtos'] = dim_produto_df['categoria_produtos'].fillna('Outros')

# Verificar o resultado
print(dim_produto_df['categoria_produtos'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'product_category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-7ab5053c08df> in <cell line: 90>()
#      88
# ...

# %% [markdown]
# ### 3.3 - Dimensão Cliente

# %%
# Mesclar clientes com a tabela de geolocalização agregada
dim_cliente_df = clientes_df.merge(
    geolocalizacao_agg,
    left_on='customer_zip_code_prefix',
    right_on='geolocation_zip_code_prefix',
    how='left'
)

# Selecionar colunas relevantes e remover duplicatas
dim_cliente_df = dim_cliente_df[[
    'customer_unique_id',
    'customer_zip_code_prefix',
    'customer_city',
    'customer_state',
    'geolocation_lat',
    'geolocation_lng'
]].drop_duplicates()

# Renomear colunas para padronização
dim_cliente_df.rename(columns={
    'customer_unique_id': 'id_cliente_unico',
    'customer_zip_code_prefix': 'cep_cliente',
    'customer_city': 'cidade_cliente',
    'customer_state': 'estado_cliente',
    'geolocation_lat': 'latitude',
    'geolocation_lng': 'longitude'
}, inplace=True)

# %% [markdown]
# ### 3.4 - Dimensão Vendedor

# %%
# Mesclar geolocalização com vendedores usando o zip code
dim_vendedor_df = vendedores_df.merge(
    geolocalizacao_df,
    left_on='seller_zip_code_prefix',
    right_on='geolocation_zip_code_prefix',
    how='left'
)

# Selecionar colunas relevantes e remover duplicatas
dim_vendedor_df = dim_vendedor_df[[
    'seller_id',
    'seller_zip_code_prefix',
    'seller_city',
    'seller_state',
    'geolocation_lat',
    'geolocation_lng'
]].drop_duplicates()

# Renomear colunas para padronização
dim_vendedor_df.rename(columns={
    'seller_id': 'id_vendedor',
    'seller_zip_code_prefix': 'cep_vendedor',
    'seller_city': 'cidade_vendedor',
    'seller_state': 'estado_vendedor',
    'geolocation_lat': 'latitude',
    'geolocation_lng': 'longitude'
}, inplace=True)

# %% [markdown]
# ### 3.5 - Dimensão Tempo

# %%
# Definir o período para a dimensão tempo
min_data = pedidos_df['order_purchase_timestamp'].min().date()
max_data = pedidos_df['order_purchase_timestamp'].max().date()

# Criar a tabela de dimensão tempo
dim_tempo_df = pd.DataFrame({'data': pd.date_range(start=min_data, end=max_data)})

# Adicionar atributos de tempo
dim_tempo_df['id_tempo'] = dim_tempo_df['data']
dim_tempo_df['ano'] = dim_tempo_df['data'].dt.year
dim_tempo_df['mes'] = dim_tempo_df['data'].dt.month
dim_tempo_df['dia'] = dim_tempo_df['data'].dt.day
dim_tempo_df['nome_mes'] = dim_tempo_df['data'].dt.strftime('%B')
dim_tempo_df['trimestre'] = dim_tempo_df['data'].dt.quarter
dim_tempo_df['dia_semana'] = dim_tempo_df['data'].dt.weekday + 1
dim_tempo_df['nome_dia_semana'] = dim_tempo_df['data'].dt.strftime('%A')

# %% [markdown]
# ### 3.6 - Dimensão Pagamento

# %%
# Criar a tabela de dimensão pagamento
dim_pagamento_df = pagamentos_df[['payment_type']].drop_duplicates()

# Adicionar um identificador para cada tipo de pagamento
dim_pagamento_df['id_pagamento'] = dim_pagamento_df.reset_index().index + 1

# Renomear colunas para padronização
dim_pagamento_df.rename(columns={'payment_type': 'tipo_pagamento'}, inplace=True)

# %% [markdown]
# # IV - Ajustes Finais nas Tabelas

# %% [markdown]
# ### 4.1 - Adicionando Data de Compra e Chaves de Tempos

# %%
# Adicionar data de compra à tabela de vendas
vendas_df = vendas_df.merge(
    pedidos_df[['order_id', 'order_purchase_timestamp']],
    on='order_id',
    how='left'
)
vendas_df['data_compra'] = vendas_df['order_purchase_timestamp'].dt.date

# Remover colunas desnecessárias
vendas_df.drop(columns=['order_purchase_timestamp'], inplace=True)

# Adicionar chave de tempo à tabela de vendas
vendas_df['id_tempo'] = vendas_df['data_compra']

# %% [markdown]
# ### 4.2 - Mesclando Pagamentos para Obter o Tipo de Pagamento

# %%
# Adicionar informações de pagamento à tabela de vendas
vendas_df = vendas_df.merge(
    pagamentos_df[['order_id', 'payment_type']],
    on='order_id',
    how='left'
)

# Mesclar com a dimensão pagamento para obter o id_pagamento
vendas_df = vendas_df.merge(
    dim_pagamento_df,
    left_on='payment_type',
    right_on='tipo_pagamento',
    how='left'
)

# %% [markdown]
# ### 4.4 - Removendo Colunas Desnecessárias

# %%
# Remover colunas intermediárias não mais necessárias
vendas_df.drop(columns=['data_compra', 'payment_type', 'tipo_pagamento', 'product_id'], inplace=True)

dim_produto_df.drop(columns=['product_category'], inplace=True)

# %%
dim_produto_df.columns
# Out:
# Index(['id_produto', 'product_name_length', 'product_description_length',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'product_volume_cm3',
#        'product_density_g_per_cm3', 'categoria_produtos'],
#       dtype='object')

# %% [markdown]
# ### 4.5 - Tradução colunas

# %%
# Listar os nomes das colunas de cada DataFrame
colunas_dim_produto = dim_produto_df.columns.tolist()
colunas_dim_cliente = dim_cliente_df.columns.tolist()
colunas_dim_vendedor = dim_vendedor_df.columns.tolist()
colunas_dim_tempo = dim_tempo_df.columns.tolist()
colunas_dim_pagamento = dim_pagamento_df.columns.tolist()

# Exibir os nomes das colunas
{
    "dim_produto": colunas_dim_produto,
    "dim_cliente": colunas_dim_cliente,
    "dim_vendedor": colunas_dim_vendedor,
    "dim_tempo": colunas_dim_tempo,
    "dim_pagamento": colunas_dim_pagamento,
}
# Out:
# {'dim_produto': ['id_produto',
#   'product_name_length',
#   'product_description_length',
#   'product_photos_qty',
#   'product_weight_g',
#   'product_length_cm',
#   'product_height_cm',
#   'product_width_cm',
#   'product_volume_cm3',
#   'product_density_g_per_cm3',
#   'categoria_produtos'],
#  'dim_cliente': ['id_cliente_unico',
#   'cep_cliente',
#   'cidade_cliente',
#   'estado_cliente',
#   'latitude',
#   'longitude'],
#  'dim_vendedor': ['id_vendedor',
#   'cep_vendedor',
#   'cidade_vendedor',
#   'estado_vendedor',
#   'latitude',
#   'longitude'],
#  'dim_tempo': ['data',
#   'id_tempo',
#   'ano',
#   'mes',
#   'dia',
#   'nome_mes',
#   'trimestre',
#   'dia_semana',
#   'nome_dia_semana'],
#  'dim_pagamento': ['tipo_pagamento', 'id_pagamento']}

# %%
# Renomear as colunas da tabela dim_produto_df

dim_produto_df.rename(columns={
    'product_name_length': 'tamanho_nome_produto',
    'product_description_length': 'tamanho_descricao_produto',
    'product_photos_qty': 'quantidade_fotos_produto',
    'product_weight_g': 'peso_produto_g',
    'product_length_cm': 'comprimento_produto_cm',
    'product_height_cm': 'altura_produto_cm',
    'product_width_cm': 'largura_produto_cm',
    'product_volume_cm3': 'volume_produto_cm3',
    'product_density_g_per_cm3': 'densidade_produto_g_por_cm3'
}, inplace=True)


# Renomear as colunas da tabela vendas_df
vendas_df.rename(columns={
    'order_id': 'id_pedido',
    'order_item_id': 'id_item_pedido',
    'seller_id': 'id_vendedor',
    'customer_id': 'id_cliente',
    'customer_unique_id': 'id_cliente_unico',
    'price': 'preco',
    'freight_value': 'valor_frete',
    'margem_bruta': 'margem_bruta',
    'shipping_limit_date': 'data_limite_envio',
    'id_tempo': 'id_tempo',
    'id_pagamento': 'id_pagamento'
}, inplace=True)

# %%
print(vendas_df.columns.tolist())
# Out:
# ['id_pedido', 'id_item_pedido', 'id_vendedor', 'id_cliente', 'id_cliente_unico', 'preco', 'valor_frete', 'margem_bruta', 'data_limite_envio', 'id_tempo', 'id_pagamento']

# %% [markdown]
# # V - Salvando as Tabelas na Camada Gold

# %% [markdown]
# ### 5.1 - Salvando Tabela Vendas

# %%
vendas_df.to_parquet(os.path.join(caminho_gold, 'vendas.parquet'), index=False)

# %% [markdown]
# ### 5.2 - Salvando Tabelas de Dimensões

# %%
dim_produto_df.to_parquet(os.path.join(caminho_gold, 'dim_produto.parquet'), index=False)
dim_cliente_df.to_parquet(os.path.join(caminho_gold, 'dim_cliente.parquet'), index=False)
dim_vendedor_df.to_parquet(os.path.join(caminho_gold, 'dim_vendedor.parquet'), index=False)
dim_tempo_df.to_parquet(os.path.join(caminho_gold, 'dim_tempo.parquet'), index=False)
dim_pagamento_df.to_parquet(os.path.join(caminho_gold, 'dim_pagamento.parquet'), index=False)

# %%
# Comparar o número de registros
print(f"Clientes: {len(dim_cliente_df)}")
print(f"Vendas: {len(vendas_df)}")
print(f"Produtos: {len(dim_produto_df)}")
print(f"Vendedores: {len(dim_vendedor_df)}")
# Out:
# Clientes: 96096
# Vendas: 98666
# Produtos: 32951
# Vendedores: 303892
